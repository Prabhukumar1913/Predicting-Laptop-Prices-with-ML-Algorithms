# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    r"C:\Users\Digoju Prabhukumar\Downloads\laptop_data.csv"
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   str
#  2   TypeName          1303 non-null   str
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   str
#  5   Cpu               1303 non-null   str
#  6   Ram               1303 non-null   str
#  7   Memory            1303 non-null   str
#  8   Gpu               1303 non-null   str
#  9   OpSys             1303 non-null   str
#  10  Weight            1303 non-null   str
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), str(9)
# memory usage: 261.0 KB

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(29)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Ram"]=df["Ram"].str.replace("GB","")

# %%
df["Weight"]=df["Weight"].str.replace("kg","")

# %%
df["Ram"]=df["Ram"].astype("int32")
df["Weight"]=df["Weight"].astype("float32")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
sns.distplot(df["Price"])
plt.title("Distplot of Price")
plt.show()
# Out:
# C:\Users\Digoju Prabhukumar\AppData\Local\Temp\ipykernel_27268\415322551.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])

# %%
df["Company"].value_counts().plot(kind="bar")
plt.title("Bar plot of Company")
plt.show()

# %%
sns.barplot(df,x="Company",y="Price")
plt.title("Bar plot of Company based on the Price_euros Point of view")
plt.xticks(rotation="vertical")
plt.show()

# %%
df["TypeName"].value_counts().plot(kind="bar")
plt.title("Bar plot of TypeName")
plt.show()

# %%
sns.barplot(df,x="TypeName",y="Price")
plt.title("Bar plot of Company based on the Price_euros Point of view")
plt.xticks(rotation="vertical")
plt.show()

# %%
sns.distplot(df["Inches"])
plt.title("Distribution of Inches columns")
plt.show()
# Out:
# C:\Users\Digoju Prabhukumar\AppData\Local\Temp\ipykernel_27268\506369061.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Inches"])

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
plt.title("Scatter plot of Inches and Price")
plt.show()

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# ### Feature engineering

# %%
df["Touchscreen"]=df["ScreenResolution"].apply(lambda x:1 if "Touchscreen" in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 1268      HP             Netbook    11.6
# 959     Acer  2 in 1 Convertible    11.6
# 7      Apple           Ultrabook    13.3
# 19      Dell           Ultrabook    13.3
# 422       HP            Notebook    15.6
#
#                                ScreenResolution  \
# 1268                                   1366x768
# 959              IPS Panel Touchscreen 1366x768
# 7                                      1440x900
# 19    IPS Panel Full HD / Touchscreen 1920x1080
# 422                           Full HD 1920x1080
#
#                                        Cpu  Ram               Memory  \
# 1268  Intel Celeron Dual Core N3060 1.6GHz    2   32GB Flash Storage
# 959   Intel Celeron Dual Core N3060 1.6GHz    4   32GB Flash Storage
# 7                     Intel Core i5 1.8GHz    8  256GB Flash Storage
# 19              Intel Core i5 8250U 1.6GHz    8            128GB SSD
# 422            Intel Core i7 7820HQ 2.9GHz    8            256GB SSD
#
# ...

# %%
df["Touchscreen"].value_counts()
# Out:
# Touchscreen
# 0    1086
# 1     188
# Name: count, dtype: int64

# %%
sns.barplot(x=df["Touchscreen"],y=df["Price"])
plt.title("Barplot of Touch screen and Price")
plt.show()

# %%
df["Ips"]=df["ScreenResolution"].apply(lambda x:1 if "IPS" in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df["Ips"].value_counts().plot(kind="bar")
plt.title("Bar plot of Ips")
plt.show()

# %%
sns.barplot(x=df["Ips"],y=df["Price"])
plt.title("Barplot of Ips and Price")
plt.show()

# %%
new=df["ScreenResolution"].str.split('x',n=1,expand=True)  # It split based on the "x" mark and expand=True makes dataFrame

# %%
df["X_res"]=new[0]
df["Y_res"]=new[1]

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches   ScreenResolution  \
# 844       HP  Ultrabook    14.0  Full HD 1920x1080
# 34     Apple  Ultrabook    13.3           1440x900
# 1141     MSI     Gaming    15.6  Full HD 1920x1080
# 97      Dell   Notebook    15.6  Full HD 1920x1080
# 797     Dell   Notebook    15.6           1366x768
#
#                               Cpu  Ram                Memory  \
# 844    Intel Core i7 6500U 2.5GHz    8             512GB SSD
# 34           Intel Core i5 1.6GHz    8   256GB Flash Storage
# 1141  Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
# 97       Intel Core i3 6006U 2GHz    4             256GB SSD
# 797    Intel Core i5 7200U 2.5GHz    8             128GB SSD
#
#                           Gpu       OpSys  Weight      Price  Touchscreen  \
# 844     Intel HD Graphics 520   Windows 7    1.54  99633.600            0
# 34     Intel HD Graphics 6000    Mac OS X    1.35  53173.440            0
# ...

# %%
df["X_res"]=df["X_res"].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   str
#  1   TypeName          1274 non-null   str
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   str
#  4   Cpu               1274 non-null   str
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   str
#  7   Gpu               1274 non-null   str
#  8   OpSys             1274 non-null   str
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  Ips               1274 non-null   int64
#  13  X_res             1274 non-null   str
#  14  Y_res             1274 non-null   str
# dtypes: float32(1), float64(2), int32(1), int64(2), str(9)
# memory usage: 275.2 KB

# %%
df["X_res"]=df["X_res"].astype('int')
df["Y_res"]=df["Y_res"].astype('int')

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# Ips            0.250358
# X_res          0.552074
# Y_res          0.548111
# Name: Price, dtype: float64

# %%
df["ppi"]= (((df["X_res"]**2) + (df["Y_res"]**2))**0.5/df["Inches"]).astype("float")

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# Ips            0.250358
# X_res          0.552074
# Y_res          0.548111
# ppi            0.469539
# Name: Price, dtype: float64

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'Touchscreen', 'Ips',
#        'X_res', 'Y_res', 'ppi'],
#       dtype='str')

# %%
df.drop(columns=["ScreenResolution","X_res","Y_res"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi
# 0   71378.6832            0    1  226.983005
# 1   47895.5232            0    0  127.677940
# ...

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       132
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M 6Y54 1.1GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# AMD E-Series 9000 2.2GHz           1
# Intel Core M 6Y30 0.9GHz           1
# AMD A9-Series 9410 2.9GHz          1
# Name: count, Length: 118, dtype: int64

# %%
df["Cpu_name"]= df["Cpu"].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi       Cpu_name
# 0   71378.6832            0    1  226.983005  Intel Core i5
# 1   47895.5232            0    0  127.677940  Intel Core i5
# ...

# %%
def fetch_processor(text):
    if text=="Intel Core i7" or text== "Intel Core i5" or  text== "Intel Core i3":
        return text
    else:
        if text.split()[0]=="Intel":
            return "Other Intel Processor"
        else:
            "return AMD Processor"

# %%
df["Cpu_brand"]=df["Cpu_name"].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi       Cpu_name      Cpu_brand
# 0   71378.6832            0    1  226.983005  Intel Core i5  Intel Core i5
# ...

# %%
df["Cpu_brand"].value_counts().plot(kind="bar")
plt.title("bar plot of Cpu_brand")
plt.show()

# %%
sns.barplot(x=df["Cpu_brand"],y=df["Price"])
plt.title("barplot of Cpu_brand and Price")
plt.show()

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi       Cpu_name      Cpu_brand
# 0   71378.6832            0    1  226.983005  Intel Core i5  Intel Core i5
# ...

# %%
df.drop(columns=["Cpu","Cpu_name"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu_brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# ...

# %%
df["Ram"].value_counts().plot(kind="bar")
plt.show()

# %%
sns.barplot(x=df["Ram"],y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
# Convert Memory column to string and clean it
df['Memory'] = df['Memory'].astype(str)
df['Memory'] = df['Memory'].str.replace('\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '', regex=False)
df['Memory'] = df['Memory'].str.replace('TB', '000', regex=False)

# Split storage types
new = df['Memory'].str.split('+', n=1, expand=True)

df['first'] = new[0].fillna('0').astype(str).str.strip()
df['second'] = new[1].fillna('0').astype(str).str.strip()

# Layer 1 storage type indicators
df['Layer1HDD'] = df['first'].apply(lambda x: 1 if 'HDD' in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x: 1 if 'SSD' in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x: 1 if 'Hybrid' in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

# Extract numeric value from first storage
df['first'] = df['first'].str.replace(r'\D', '', regex=True)

# Layer 2 storage type indicators
df['Layer2HDD'] = df['second'].apply(lambda x: 1 if 'HDD' in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x: 1 if 'SSD' in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x: 1 if 'Hybrid' in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

# Extract numeric value from second storage
df['second'] = df['second'].str.replace(r'\D', '', regex=True)

# Replace empty strings with 0
df['first'] = df['first'].replace('', '0')
df['second'] = df['second'].replace('', '0')

# Convert to integer
df['first'] = df['first'].astype(int)
df['second'] = df['second'].astype(int)

# Final storage capacities
df['HDD'] = (df['first'] * df['Layer1HDD']) + (df['second'] * df['Layer2HDD'])
df['SSD'] = (df['first'] * df['Layer1SSD']) + (df['second'] * df['Layer2SSD'])
df['Hybrid'] = (df['first'] * df['Layer1Hybrid']) + (df['second'] * df['Layer2Hybrid'])
df['Flash_Storage'] = (df['first'] * df['Layer1Flash_Storage']) + (df['second'] * df['Layer2Flash_Storage'])

# Drop temporary columns
df.drop(columns=[
    'first', 'second',
    'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)

print(df[['Memory', 'HDD', 'SSD', 'Hybrid', 'Flash_Storage']].head())
# Out:
#               Memory  HDD  SSD  Hybrid  Flash_Storage
# 0            128 SSD    0  128       0              0
# 1  128 Flash Storage    0    0       0            128
# 2            256 SSD    0  256       0              0
# 3            512 SSD    0  512       0              0
# 4            256 SSD    0  256       0              0

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2      HP   Notebook    15.6    8            256 SSD
# 3   Apple  Ultrabook    15.4   16            512 SSD
# 4   Apple  Ultrabook    13.3    8            256 SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu_brand  HDD  SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5    0  128       0              0
# ...

# %%
df.drop(columns=["Memory"],inplace=True)

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches           0.066990
# Ram              0.740106
# Weight           0.212192
# Price            1.000000
# Touchscreen      0.188631
# Ips              0.250358
# ppi              0.469539
# HDD             -0.098011
# SSD              0.669957
# Hybrid           0.022533
# Flash_Storage   -0.037176
# Name: Price, dtype: float64

# %%
df.drop(columns=["Hybrid","Flash_Storage"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight        Price  Touchscreen  Ips         ppi      Cpu_brand  HDD  SSD
# 0    1.37   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1    1.34   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2    1.86   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3    1.83  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4    1.37   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df["Gpu_brand"]=df["Gpu"].apply(lambda x:x.split()[0])

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df["Gpu_brand"] != "ARM"]

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     703
# Nvidia    396
# AMD       174
# Name: count, dtype: int64

# %%
sns.barplot(x=df["Gpu_brand"],y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
df.drop(columns=["Gpu"],inplace=True)

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df["OpSys"],y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df["os"]=df["OpSys"].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    13.3    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    13.3    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    15.6    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook    15.4   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    13.3    8  macOS    1.37   96095.8080            0
#
#    Ips         ppi      Cpu_brand  HDD  SSD Gpu_brand                  os
# 0    1  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1    0  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2    0  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3    1  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4    1  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=["OpSys"],inplace=True)

# %%
sns.distplot(df['Weight'])
plt.title("distplot of Weight")
plt.show()
# Out:
# C:\Users\Digoju Prabhukumar\AppData\Local\Temp\ipykernel_27268\4137857873.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])

# %%
    sns.scatterplot(x=df['Weight'],y=df['Price'])
    plt.title("Scatter plot of Weight and Price")
    plt.show()

# %%
df.corr(numeric_only=True)["Price"]
# Out:
# Inches         0.066079
# Ram            0.739996
# Weight         0.211667
# Price          1.000000
# Touchscreen    0.190382
# Ips            0.251514
# ppi            0.471481
# HDD           -0.098481
# SSD            0.669808
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.title("Correlation with respect to price")
plt.show()

# %%
sns.distplot(df['Price'])
plt.title("Distplot of Price")
plt.show()
# Out:
# C:\Users\Digoju Prabhukumar\AppData\Local\Temp\ipykernel_27268\3633538520.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])

# %% [markdown]
# * It is skewed for that i'm are using the Log transformation.

# %%
sns.distplot(np.log(df['Price']))
plt.show()
# Out:
# C:\Users\Digoju Prabhukumar\AppData\Local\Temp\ipykernel_27268\510932665.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))

# %%
df.drop(columns="Inches",inplace=True)

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X.sample(3)
# Out:
#      Company  TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 35    Lenovo  Notebook    4    1.44            0    0  111.935204
# 890       HP  Notebook    4    1.95            0    0  157.350512
# 1214    Asus    Gaming   16    2.90            0    0  127.335675
#
#                   Cpu_brand   HDD  SSD Gpu_brand       os
# 35    Other Intel Processor     0    0     Intel  Windows
# 890           Intel Core i5     0  128     Intel  Windows
# 1214          Intel Core i7  1000  256    Nvidia  Windows

# %%
y.sample(3)
# Out:
# 557    10.83097
# 317    10.10657
# 202    10.58491
# Name: Price, dtype: float64

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# # Linear regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.783156711545016
# MAE 0.22167696491055228

# %% [markdown]
# ## Ridge regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7976251273419546
# MAE 0.21716007488167258

# %% [markdown]
# ## Lasso regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7939495673998733
# MAE 0.21841822400572308

# %% [markdown]
# # KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7639728764861157
# MAE 0.20605747789780496

# %% [markdown]
# # Decision tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8036846144548464
# MAE 0.2085207216064869

# %% [markdown]
# # SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8286019373070553
# MAE 0.19749018481005784

# %% [markdown]
# ## Observations:
# * With the decision tree algorithm it's showing the more accuracy and less error

# %% [markdown]
# # Exporting Model

# %%
import pickle

pickle.dump(df,open('df7.pkl','wb'))
pickle.dump(pipe,open('pipe7.pkl','wb'))
